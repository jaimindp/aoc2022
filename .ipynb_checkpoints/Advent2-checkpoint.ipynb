# %%
import pandas as pd

# %%
df = pd.read_csv('input.txt', )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c326f8fda941> in <module>
# ----> 1 df = pd.read_csv('input.txt', index=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
lines = open('input.txt')
lines = lines.readlines()
lines
# Out:
# ['A Y\n',
#  'A Z\n',
#  'A X\n',
#  'B X\n',
#  'A Y\n',
#  'B Y\n',
#  'B Y\n',
#  'A X\n',
#  'A Z\n',
#  'A X\n',
#  'A X\n',
#  'A X\n',
#  'B X\n',
#  'B X\n',
#  'B X\n',
#  'B X\n',
#  'C Z\n',
#  'B Z\n',
#  'B Y\n',
#  'B X\n',
#  'A X\n',
#  'A Y\n',
#  'B X\n',
#  'B X\n',
#  'B X\n',
#  'B Z\n',
#  'B X\n',
#  'B X\n',
#  'B X\n',
#  'B Z\n',
#  'B Z\n',
#  'A X\n',
#  'A X\n',
#  'C X\n',
#  'B X\n',
#  'B X\n',
#  'B X\n',
#  'A X\n',
#  'B X\n',
#  'B X\n',
#  'A Z\n',
#  'B X\n',
#  'B X\n',
#  'B X\n',
#  'B Z\n',
#  'B X\n',
#  'A X\n',
#  'B X\n',
#  'B Z\n',
#  'B X\n',
#  'B X\n',
#  'B Z\n',
#  'A Z\n',
#  'B X\n',
#  'B X\n',
#  'B X\n',
#  'A X\n',
#  'C Z\n',
#  'A X\n',
#  'A X\n',
#  'C Y\n',
#  'A X\n',
#  'B X\n',
#  'B X\n',
#  'B X\n',
#  'A X\n',
#  'B X\n',
#  'B X\n',
#  'A X\n',
#  'C X\n',
#  'B Y\n',
#  'A Z\n',
#  'A Y\n',
#  'B Z\n',
#  'B Z\n',
#  'C X\n',
#  'B Y\n',
#  'A X\n',
#  'B Y\n',
#  'A Y\n',
#  'B X\n',
#  'C X\n',
#  'B X\n',
# ...

# %%
inputs = [i.split() for i in lines]

# %%
# Win + 6
# Lose 0
# Draw + 3
p1dict ={'A':1, 'B': 2, 'C': 3}
p2dict ={'X':1, 'Y': 2, 'Z': 3}
        # Rock, #Scis, Rock,    # Paper,  #Paper  rock     
p1win = {'A':{'X':0+3, 'Y':3+1, 'Z':6+2}, 'B':{'X':0+1, 'Y':3+2, 'Z':6+3}, 'C':{'X':0+2, 'Y':3+3, 'Z':6+1}}
p2win = {'X':{'A':3, 'B': 0, 'C':6}, 'Y':{'A':6, 'B':3, 'C':0}, 'Z':{'A':0, 'B': 6, 'C':3}}

# %%
inputs
# Out:
# [['A', 'Y'],
#  ['A', 'Z'],
#  ['A', 'X'],
#  ['B', 'X'],
#  ['A', 'Y'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['A', 'X'],
#  ['A', 'Z'],
#  ['A', 'X'],
#  ['A', 'X'],
#  ['A', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['C', 'Z'],
#  ['B', 'Z'],
#  ['B', 'Y'],
#  ['B', 'X'],
#  ['A', 'X'],
#  ['A', 'Y'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'Z'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'Z'],
#  ['B', 'Z'],
#  ['A', 'X'],
#  ['A', 'X'],
#  ['C', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['A', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['A', 'Z'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'Z'],
#  ['B', 'X'],
#  ['A', 'X'],
#  ['B', 'X'],
#  ['B', 'Z'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'Z'],
#  ['A', 'Z'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['A', 'X'],
#  ['C', 'Z'],
#  ['A', 'X'],
#  ['A', 'X'],
#  ['C', 'Y'],
#  ['A', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['A', 'X'],
# ...

# %%
tot = 0 

for i in inputs:
    tot += p2win[i[1]][i[0]] + p2dict[i[1]]
    
print(tot)
# Out:
# 10595

# %%
# 2 X need to lose, y need to draw, z need to win

# %%
win_dict = {'X':0, 'Y':3, 'Z':6}

# %%
'A'

# %%
tot = 0 

for i in inputs:
    tot += p1win[i[0]][i[1]]
    
print(tot)
# Out:
# 9541
